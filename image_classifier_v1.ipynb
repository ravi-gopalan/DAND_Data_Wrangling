# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-gopalan/DAND_Data_Wrangling/blob/master/image_classifier_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classifier Model Creation / Refresh

# %% [markdown]
# # Mount Google Drive to load the files
#
# ## FastAI requires GPU resources for optimal performance. Images for training the Image Classifier model have been loaded onto Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# # Import the libraries onto the Jupyter notebook
#
# The ```InteractiveShell.ast_node_interactivity = 'all'``` setting ensures visibility into multiple outputs for each cell

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## The libraries required are the following
#
# - ```fastai``` and ```fastai.vision``` for image model building
# - ```numpy``` and ```pandas``` for vector operations
# - ```os``` and ```time``` for general processing

# %%
from fastai import *
from fastai.vision import *

import numpy as np
import pandas as pd
import os
import time

# %% [markdown]
# # Setup the directories where the images are stored
#
# The images in the ```image_dir``` folder has the following structure. This makes it easy to create the data for processing
#
# ```
# image_dir
# │
# └───train
# │   └───approved
# │   │    │   image1.jpg
# │   │    │   ...
# │   │
# │   └───ineligible
# │   │    │   image1.jpg
# │   │    │   ...
# │
# └───valid
# │   └───approved
# │   │    │   image1.jpg
# │   │    │   ...
# │   │
# │   └───ineligible
# │   │    │   image1.jpg
# │   │    │   ...
# │
# └───test
# │   └───approved
# │   │    │   image1.jpg
# │   │    │   ...
# │   │
# │   └───ineligible
# │   │    │   image1.jpg
# │   │    │   ...
# ```

# %%
image_dir = '/gdrive/My Drive/abv_reviews/images'
# The predict_dir has some images which are currently in the pending stage for inference 
predict_dir = '/gdrive/My Drive/abv_reviews/pending_images'

# %%
# Number of files in the train, valid, and test folder and sub-folders
print('Train: Approved {}, Ineligible {}'.format(len(os.listdir(image_dir+'/train/approved')), len(os.listdir(image_dir+'/train/ineligible'))))
print('Valid: Approved {}, Ineligible {}'.format(len(os.listdir(image_dir+'/valid/approved')), len(os.listdir(image_dir+'/valid/ineligible'))))
print('Test: Approved {}, Ineligible {}'.format(len(os.listdir(image_dir+'/test/approved')), len(os.listdir(image_dir+'/test/ineligible'))))
# Out:
# Train: Approved 1015, Ineligible 206
# Valid: Approved 218, Ineligible 44
# Test: Approved 225, Ineligible 45

# %% [markdown]
# # Create Databunch for fastai

# %%
data = (ImageList.from_folder(image_dir)
        .split_by_folder()          
        .label_from_folder()
        .transform(get_transforms(do_flip=False), size=224)
        .databunch(bs=32)
        .normalize(imagenet_stats))

# The classes of the data are approved and ineligible
len(data.classes)
# Out:
# 2

# %% [markdown]
# # Create a Learner
#
# The resnet34 pre-trained model is used and will be downloaded.
#
# The metrics to be optimized are ```error_rate, accuracy, precision, recall and FBeta```

# %%
learn_resnet34 = cnn_learner(data, models.resnet34, metrics=[error_rate,accuracy, Recall(average='macro'), Precision(average='macro'),FBeta(average='macro')])

# Fit for 2 cycles
learn_resnet34.fit_one_cycle(2)

# Save the model generated as stage_1_resnet34
learn_resnet34.save('stage_1_resnet34')

# Find out learning rate
learn_resnet34.lr_find()

# Plot learning rate. This will enable us to determine the best learning rate for further training.
learn_resnet34.recorder.plot()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 95.8MB/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.101177</td>
#       <td>0.828996</td>
#       <td>0.305344</td>
#       <td>0.694656</td>
#       <td>0.698603</td>
#       <td>0.618529</td>
#       <td>0.647229</td>
#       <td>13:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.750188</td>
#       <td>0.517655</td>
#       <td>0.229008</td>
#       <td>0.770992</td>
#       <td>0.662844</td>
#       <td>0.628878</td>
#       <td>0.652045</td>
#       <td>01:35</td>
#     </tr>
#   </tbody>
# </table>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# # Model Training

# %%
# Unfreeze the resnet34 model

learn_resnet34.unfreeze()

# Run the training for 20 cycles for the best learning rate that was determined in the previous step
learn_resnet34.fit_one_cycle(20, max_lr = slice(1e-6,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.462144</td>
#       <td>0.448840</td>
#       <td>0.167939</td>
#       <td>0.832061</td>
#       <td>0.636051</td>
#       <td>0.687500</td>
#       <td>0.641731</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.424229</td>
#       <td>0.551278</td>
#       <td>0.156489</td>
#       <td>0.843511</td>
#       <td>0.706422</td>
#       <td>0.718519</td>
#       <td>0.708625</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.400065</td>
#       <td>0.595924</td>
#       <td>0.179389</td>
#       <td>0.820611</td>
#       <td>0.692661</td>
#       <td>0.682880</td>
#       <td>0.690519</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.390375</td>
#       <td>0.659367</td>
#       <td>0.183206</td>
#       <td>0.816794</td>
#       <td>0.626877</td>
#       <td>0.656992</td>
#       <td>0.630844</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.332417</td>
#       <td>0.893901</td>
#       <td>0.217557</td>
#       <td>0.782443</td>
#       <td>0.687865</td>
#       <td>0.646970</td>
#       <td>0.674879</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.293241</td>
#       <td>1.209181</td>
#       <td>0.259542</td>
#       <td>0.740458</td>
#       <td>0.680776</td>
#       <td>0.622666</td>
#       <td>0.654912</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.242924</td>
#       <td>0.841672</td>
#       <td>0.152672</td>
#       <td>0.847328</td>
#       <td>0.645225</td>
#       <td>0.727021</td>
#       <td>0.652701</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.200939</td>
#       <td>1.071721</td>
#       <td>0.259542</td>
#       <td>0.740458</td>
#       <td>0.635425</td>
#       <td>0.600417</td>
#       <td>0.621905</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.203148</td>
#       <td>0.826112</td>
#       <td>0.141221</td>
#       <td>0.858779</td>
#       <td>0.697456</td>
#       <td>0.750629</td>
#       <td>0.704720</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.142092</td>
#       <td>0.782406</td>
#       <td>0.122137</td>
#       <td>0.877863</td>
#       <td>0.699854</td>
#       <td>0.812419</td>
#       <td>0.711232</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.098671</td>
#       <td>0.817346</td>
#       <td>0.133588</td>
#       <td>0.866412</td>
#       <td>0.720183</td>
#       <td>0.765828</td>
#       <td>0.726997</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.075057</td>
#       <td>0.936195</td>
#       <td>0.141221</td>
#       <td>0.858779</td>
#       <td>0.661176</td>
#       <td>0.760928</td>
#       <td>0.670150</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.059449</td>
#       <td>0.756125</td>
#       <td>0.133588</td>
#       <td>0.866412</td>
#       <td>0.692973</td>
#       <td>0.773938</td>
#       <td>0.702296</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.041341</td>
#       <td>0.797350</td>
#       <td>0.133588</td>
#       <td>0.866412</td>
#       <td>0.692973</td>
#       <td>0.773938</td>
#       <td>0.702296</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.029449</td>
#       <td>0.869001</td>
#       <td>0.133588</td>
#       <td>0.866412</td>
#       <td>0.711113</td>
#       <td>0.767963</td>
#       <td>0.718953</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.025305</td>
#       <td>0.888913</td>
#       <td>0.122137</td>
#       <td>0.877863</td>
#       <td>0.708924</td>
#       <td>0.805861</td>
#       <td>0.719782</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.028910</td>
#       <td>0.908814</td>
#       <td>0.118321</td>
#       <td>0.881679</td>
#       <td>0.684008</td>
#       <td>0.848745</td>
#       <td>0.696419</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.020763</td>
#       <td>0.876969</td>
#       <td>0.129771</td>
#       <td>0.870229</td>
#       <td>0.677127</td>
#       <td>0.797444</td>
#       <td>0.687725</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.018938</td>
#       <td>0.922995</td>
#       <td>0.114504</td>
#       <td>0.885496</td>
#       <td>0.695371</td>
#       <td>0.854924</td>
#       <td>0.708388</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.018193</td>
#       <td>0.851195</td>
#       <td>0.122137</td>
#       <td>0.877863</td>
#       <td>0.690784</td>
#       <td>0.820378</td>
#       <td>0.702477</td>
#       <td>01:34</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Interpretation of the model's results

# %%
# Interpret the model that has been generated and then identify the images for which the loss is the highest

interp_resnet34 = ClassificationInterpretation.from_learner(learn_resnet34)
interp_resnet34.plot_top_losses(12, figsize=(15,15))


# Plot the confusion matrix that visually represents the model's accuracy, precision and recall
interp_resnet34.plot_confusion_matrix()

# %% [markdown]
# # Interpret results

# %% [markdown]
# The confusion matrix indicates that the model classified 212 test images correctly as approved and 18 correctly as ineligible
#
# The model also predicted 26 of the images as approved while they were ineligible and 6 images as ineligible while they were in fact approved.

# %% [markdown]
# ## Save the model as stage_2_resnet34

# %%
learn_resnet34.save('stage_2_resnet34')

# %% [markdown]
# # Predict
#
# Use the model to classify images that are currently in the pending category

# %%
pending_list = os.listdir(predict_dir)
len(pending_list)

# %% [markdown]
# ## Predict for a random sample of images

# %%
file_list = [predict_dir+file for file in list(np.random.choice(pending_list, size=5, replace=False))]
for pic in file_list:
  open_image(pic).resize(400)
  predicted_status, tensor_index, probability_tensor = learn_resnet34.predict(open_image(pic).resize(200))
  prob = max(probability_tensor[0].item(),probability_tensor[1].item())
  print('{:.2f}% probability of review being {} \n'.format(100*prob, predicted_status.obj))
  time.sleep(5)
# Out:
# Image (3, 1080, 810)
# 100.00% probability of review being approved
# Image (3, 1080, 810)
# 100.00% probability of review being approved
# Image (3, 2488, 3319)
# 99.29% probability of review being approved
# Image (3, 1080, 810)
# 100.00% probability of review being approved
# Image (3, 1080, 810)
# 81.09% probability of review being ineligible
